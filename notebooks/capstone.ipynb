# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# # Federal Housing Finance Agency
# # FHLBank Public Use Database
# homes = pd.read_csv('../data/2019_PUDB_EXPORT_123119.csv')

# %%
# # TN Report Card
# reportcard = pd.read_excel('../data/reportcarddata20191.xlsx')

# %%
# Metro Nashville Public Schools
# MNPS Enrollment and Demographics
mnps = pd.read_excel('../data/MNPSEnrollmentData121219.xls')

# %%
# # Census: American Community Survey
# acs = pd.read_csv('../data/acs_data/productDownload_2021-03-25T213215/ACSDP1Y2019.DP05_data_with_overlays_2021-03-25T213212.csv')

# %%
# CensusReporter: Davidson County, TN Household Income in the Past 12 Months (2019)
cr_income = pd.read_csv('../data/acs2019_1yr_B19001_01000US/acs2019_1yr_B19001_01000US.csv')

# %%
# CensusReporter: Davidson County, TN Household Income in the Past 12 Months (2019) (metadata)
cr_income_metadata = pd.read_json('../data/acs2019_1yr_B19001_01000US/metadata.json')

# %%
# TN Ready to Graduate by District 2019-2020 (Data maybe affected due to pandemic and regulations)
ready_grad_19 = pd.read_csv('../data/ready_graduate_district_suppressed.csv')

# %%
# TN Ready to Graduate by District 2018-2019
ready_grad_18 = pd.read_excel('../data/2018-19_ready_grad_district_suppressed.csv.xlsx')

# %%
# TN ACT Score Data by District
act_19 = pd.read_csv('../data/ACT_district_suppressed_2020.csv')

# %%
# TN School Indicator Scores by District
school_indicators_19 = pd.read_csv('../data/school_indicator_scores_suppressed.csv')

# %% [markdown]
# ### MNPS Exploration

# %%
mnps.shape
# Out:
# (167, 34)

# %%
mnps['Zip Code'].unique()
# Out:
# array([37013, 37189, 37115, 37138, 37221, 37207, 37208, 37203, 37211,
#        37209, 37206, 37218, 37220, 37216, 37076, 37214, 37212, 37204,
#        37217, 37072, 37027, 37205, 37215, 37080, 37210, 37228])

# %%
mnps.head()
# Out:
#   School Year       School Level  School ID                School Name  \
# 0       19-20  Elementary School        496    A. Z. Kelley Elementary
# 1       19-20  Elementary School        375      Alex Green Elementary
# 2       19-20  Elementary School        105           Amqui Elementary
# 3       19-20  Elementary School        460  Andrew Jackson Elementary
# 4       19-20        High School        110        Antioch High School
#
#    State School ID  Zip Code  Total Enrollment Grade PreK 3yrs  \
# 0                1     37013               849             NaN
# 1                5     37189               236            < 10
# 2               10     37115               466            < 10
# 3               15     37138               494            < 10
# 4               20     37013              1929             NaN
#
#   Grade PreK 4yrs Grade K  ... Black or African American Hispanic/Latino  \
# 0            < 5%     18%  ...                       37%             24%
# ...

# %%
mnps.tail()
# Out:
#     School Year       School Level  School ID                  School Name  \
# 162       19-20      Middle School        770              West End Middle
# 163       19-20  Elementary School        775         Westmeade Elementary
# 164       19-20        High School        787     Whites Creek High School
# 165       19-20      Middle School        612  William Henry Oliver Middle
# 166       19-20      Middle School        805                Wright Middle
#
#      State School ID  Zip Code  Total Enrollment Grade PreK 3yrs  \
# 162              690     37205               502             NaN
# 163              695     37205               425             NaN
# 164              704     37189               527             NaN
# 165              538     37211               979             NaN
# 166              715     37211               813             NaN
#
#     Grade PreK 4yrs Grade K  ... Black or African American Hispanic/Latino  \
# ...

# %%
# homes.shape

# %%
# homes.head()

# %%
# reportcard.shape

# %%
# reportcard.head(5)

# %%
# acs.shape

# %%
# acs.head()

# %%
# cr_income.shape

# %%
# cr_income.head()

# %%
mnps.head()
# Out:
#   School Year       School Level  School ID                School Name  \
# 0       19-20  Elementary School        496    A. Z. Kelley Elementary
# 1       19-20  Elementary School        375      Alex Green Elementary
# 2       19-20  Elementary School        105           Amqui Elementary
# 3       19-20  Elementary School        460  Andrew Jackson Elementary
# 4       19-20        High School        110        Antioch High School
#
#    State School ID  Zip Code  Total Enrollment Grade PreK 3yrs  \
# 0                1     37013               849             NaN
# 1                5     37189               236            < 10
# 2               10     37115               466            < 10
# 3               15     37138               494            < 10
# 4               20     37013              1929             NaN
#
#   Grade PreK 4yrs Grade K  ... Black or African American Hispanic/Latino  \
# 0            < 5%     18%  ...                       37%             24%
# ...

# %% [markdown]
# ### MNPS High School Subset

# %%
mnps_hs = mnps.loc[mnps['School Level'] == 'High School']

# %%
mnps_hs.shape
# Out:
# (17, 34)

# %%
mnps_hs.head(2)
# Out:
#    School Year School Level  School ID             School Name  \
# 4        19-20  High School        110     Antioch High School
# 13       19-20  High School        182  Cane Ridge High School
#
#     State School ID  Zip Code  Total Enrollment Grade PreK 3yrs  \
# 4                20     37013              1929             NaN
# 13               77     37013              1870             NaN
#
#    Grade PreK 4yrs Grade K  ... Black or African American Hispanic/Latino  \
# 4              NaN     NaN  ...                       33%             43%
# 13             NaN     NaN  ...                       40%             35%
#
#    Native Hawaiian or Other Pacific Islander White Male Female  \
# 4                                       < 10   20%  54%    46%
# 13                                      < 10   17%  53%    47%
#
#    Economically Disadvantaged Students with Disabilities  \
# 4                         32%                         9%
# ...

# %%
mnps_hs.columns
# Out:
# Index(['School Year', 'School Level', 'School ID', 'School Name',
#        'State School ID', 'Zip Code', 'Total Enrollment', 'Grade PreK 3yrs',
#        'Grade PreK 4yrs', 'Grade K', 'Grade 1', 'Grade 2', 'Grade 3',
#        'Grade 4', 'Grade 5', 'Grade 6', 'Grade 7', 'Grade 8', 'Grade 9',
#        'Grade 10', 'Grade 11', 'Grade 12', 'American Indian or Alaska Native',
#        'Asian', 'Black or African American', 'Hispanic/Latino',
#        'Native Hawaiian or Other Pacific Islander', 'White', 'Male', 'Female',
#        'Economically Disadvantaged', 'Students with Disabilities',
#        'Limited English Proficiency', 'DataAsOf'],
#       dtype='object')

# %% [markdown]
# ### MNPS High School Demographics

# %%
mnps_hs_dem = mnps_hs[['School Level', 'School ID',\
                            'School Name', 'State School ID',\
                            'Zip Code', 'Total Enrollment',\
                            'Economically Disadvantaged',\
                            'Students with Disabilities',\
                            'Limited English Proficiency',\
                            'Female', 'Male',\
                            'White', 'Black or African American',\
                            'Hispanic/Latino', 'Asian',\
                            'American Indian or Alaska Native',\
                            'Native Hawaiian or Other Pacific Islander',\
                            'DataAsOf']]

# %%
# mnps_hs_dem

# %%
# mnps_hs_dem.loc[4,'Economically Disadvantaged'].replace('%','ZZZ')

# %%
# df['result'] = df['result'].str.replace(r'\D', '')

# %%
mnps_hs_dem['econ_dis_pct'] = mnps_hs_dem['Economically Disadvantaged']\
    .str.replace(r'\D','').astype(float)
# Out:
# <ipython-input-33-96a9505aed42>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mnps_hs_dem['econ_dis_pct'] = mnps_hs_dem['Economically Disadvantaged']\

# %%
mnps_hs_dem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 4 to 164
# Data columns (total 19 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   School Level                               17 non-null     object
#  1   School ID                                  17 non-null     int64
#  2   School Name                                17 non-null     object
#  3   State School ID                            17 non-null     int64
#  4   Zip Code                                   17 non-null     int64
#  5   Total Enrollment                           17 non-null     int64
#  6   Economically Disadvantaged                 17 non-null     object
#  7   Students with Disabilities                 17 non-null     object
#  8   Limited English Proficiency                17 non-null     object
#  9   Female                                     17 non-null     object
# ...

# %%
mnps_hs_dem.head(2)
# Out:
#    School Level  School ID             School Name  State School ID  Zip Code  \
# 4   High School        110     Antioch High School               20     37013
# 13  High School        182  Cane Ridge High School               77     37013
#
#     Total Enrollment Economically Disadvantaged Students with Disabilities  \
# 4               1929                        32%                         9%
# 13              1870                        34%                        10%
#
#    Limited English Proficiency Female Male White Black or African American  \
# 4                          33%    46%  54%   20%                       33%
# 13                         31%    47%  53%   17%                       40%
#
#    Hispanic/Latino Asian American Indian or Alaska Native  \
# 4              43%  < 5%                             < 10
# 13             35%    7%                             < 10
#
#    Native Hawaiian or Other Pacific Islander    DataAsOf  econ_dis_pct
# ...

# %%
mnps_hs_dem['econ_dis_decimal'] = mnps_hs_dem['econ_dis_pct']
# Out:
# <ipython-input-36-46c9569e4154>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mnps_hs_dem['econ_dis_decimal'] = mnps_hs_dem['econ_dis_pct']

# %%
mnps_hs_dem.head(2)
# Out:
#    School Level  School ID             School Name  State School ID  Zip Code  \
# 4   High School        110     Antioch High School               20     37013
# 13  High School        182  Cane Ridge High School               77     37013
#
#     Total Enrollment Economically Disadvantaged Students with Disabilities  \
# 4               1929                        32%                         9%
# 13              1870                        34%                        10%
#
#    Limited English Proficiency Female Male White Black or African American  \
# 4                          33%    46%  54%   20%                       33%
# 13                         31%    47%  53%   17%                       40%
#
#    Hispanic/Latino Asian American Indian or Alaska Native  \
# 4              43%  < 5%                             < 10
# 13             35%    7%                             < 10
#
#    Native Hawaiian or Other Pacific Islander    DataAsOf  econ_dis_pct  \
# ...

# %%
mnps_hs_dem['econ_dis_decimal']/= 100.
# Out:
# <ipython-input-38-2ea14afeea31>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mnps_hs_dem['econ_dis_decimal']/= 100.

# %%
mnps_hs_dem.head(2)
# Out:
#    School Level  School ID             School Name  State School ID  Zip Code  \
# 4   High School        110     Antioch High School               20     37013
# 13  High School        182  Cane Ridge High School               77     37013
#
#     Total Enrollment Economically Disadvantaged Students with Disabilities  \
# 4               1929                        32%                         9%
# 13              1870                        34%                        10%
#
#    Limited English Proficiency Female Male White Black or African American  \
# 4                          33%    46%  54%   20%                       33%
# 13                         31%    47%  53%   17%                       40%
#
#    Hispanic/Latino Asian American Indian or Alaska Native  \
# 4              43%  < 5%                             < 10
# 13             35%    7%                             < 10
#
#    Native Hawaiian or Other Pacific Islander    DataAsOf  econ_dis_pct  \
# ...

# %%
mnps_hs_dem['econ_dis_count'] = mnps_hs_dem['Total Enrollment']*mnps_hs_dem['econ_dis_decimal']
# Out:
# <ipython-input-40-e75eef329196>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mnps_hs_dem['econ_dis_count'] = mnps_hs_dem['Total Enrollment']*mnps_hs_dem['econ_dis_decimal']

# %%
mnps_hs_dem.head(2)
# Out:
#    School Level  School ID             School Name  State School ID  Zip Code  \
# 4   High School        110     Antioch High School               20     37013
# 13  High School        182  Cane Ridge High School               77     37013
#
#     Total Enrollment Economically Disadvantaged Students with Disabilities  \
# 4               1929                        32%                         9%
# 13              1870                        34%                        10%
#
#    Limited English Proficiency Female  ... White Black or African American  \
# 4                          33%    46%  ...   20%                       33%
# 13                         31%    47%  ...   17%                       40%
#
#    Hispanic/Latino Asian American Indian or Alaska Native  \
# 4              43%  < 5%                             < 10
# 13             35%    7%                             < 10
#
#    Native Hawaiian or Other Pacific Islander    DataAsOf econ_dis_pct  \
# ...

# %%
mnps_hs_dem_sorted = mnps_hs_dem.sort_values(by = 'econ_dis_pct', ascending = False)

# %%
mnps_hs_dem_sorted.head()
# Out:
#     School Level  School ID                   School Name  State School ID  \
# 121  High School        632               Pearl-Cohn High              555
# 140  High School        705  Stratford STEM Magnet School              620
# 96   High School        550                Maplewood High              445
# 164  High School        787      Whites Creek High School              704
# 63   High School        452             Hunters Lane High              358
#
#      Zip Code  Total Enrollment Economically Disadvantaged  \
# 121     37208               605                        70%
# 140     37216               960                        61%
# 96      37216               752                        60%
# 164     37189               527                        57%
# 63      37207              1331                        44%
#
#     Students with Disabilities Limited English Proficiency Female  ... White  \
# 121                        21%                        < 5%    52%  ...  < 5%
# ...

# %%
plt.bar(mnps_hs_dem_sorted['School Name'],\
        mnps_hs_dem_sorted['econ_dis_count'],\
        color = '#53b92b')
plt.xticks(rotation=90)
plt.title('Count of Economically Disadvantaged Students per High School')
plt.xlabel('High School')
plt.ylabel('Count of Students')
plt.xticks(rotation=45,
        horizontalalignment="right")
# plt.ylim(0, 3250) 
;
# Out:
# ''

# %%
plt.bar(mnps_hs_dem_sorted['School Name'],\
        (mnps_hs_dem_sorted['econ_dis_count']/mnps_hs_dem_sorted['Total Enrollment']*100),\
        color = '#53b92b')
plt.xticks(rotation=90)
plt.title('Calculated Percentage of Economically Disadvantaged Students per High School')
plt.xlabel('High School')
plt.ylabel('Percent of Students')
plt.xticks(rotation=45,
        horizontalalignment="right")
# plt.ylim(0, 3250) 
;
# Out:
# ''

# %%
plt.bar(mnps_hs_dem_sorted['School Name'],\
        mnps_hs_dem_sorted['econ_dis_pct'],\
        color = '#53b92b')
plt.xticks(rotation=90)
plt.title('Percentage of Economically Disadvantaged Students per High School')
plt.xlabel('High School')
plt.ylabel('Percent of Students')
plt.xticks(rotation=45,
        horizontalalignment="right")
# plt.ylim(0, 3250) 
;
# Out:
# ''

# %% [markdown]
# ### Census Reporter Data Exploration of Incomes

# %%
cr_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 36 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   geoid             3 non-null      object
#  1   name              3 non-null      object
#  2   B19001001         3 non-null      int64
#  3   B19001001, Error  3 non-null      int64
#  4   B19001002         3 non-null      int64
#  5   B19001002, Error  3 non-null      int64
#  6   B19001003         3 non-null      int64
#  7   B19001003, Error  3 non-null      int64
#  8   B19001004         3 non-null      int64
#  9   B19001004, Error  3 non-null      int64
#  10  B19001005         3 non-null      int64
#  11  B19001005, Error  3 non-null      int64
#  12  B19001006         3 non-null      int64
#  13  B19001006, Error  3 non-null      int64
#  14  B19001007         3 non-null      int64
#  15  B19001007, Error  3 non-null      int64
# ...

# %%
# cr_income_metadata_labels = cr_income_metadata['tables'][3]

# %%
cr_income_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, id to B19001
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   release  3 non-null      object
#  1   tables   1 non-null      object
# dtypes: object(2)
# memory usage: 96.0+ bytes

# %%
cr_income_metadata
# Out:
#                 release                                             tables
# id          acs2019_1yr                                                NaN
# name    ACS 2019 1-year                                                NaN
# years              2019                                                NaN
# B19001              NaN  {'columns': {'B19001001': {'indent': 0, 'name'...

# %%
# type(cr_income_metadata_labels)

# %%
# cr_income_metadata_labels.values()

# %%
# cr_income_metadata_labels

# %%
# pd.DataFrame.from_records(df.codes.dropna().tolist())

# %%
cr_income_metadata_unpacked = pd.DataFrame.from_records(cr_income_metadata['tables'][3])

# %%
cr_income_metadata_unpacked.head()
# Out:
#                                                columns denominator_column_id  \
# B19001001              {'indent': 0, 'name': 'Total:'}             B19001001
# B19001002   {'indent': 1, 'name': 'Less than $10,000'}             B19001001
# B19001003  {'indent': 1, 'name': '$10,000 to $14,999'}             B19001001
# B19001004  {'indent': 1, 'name': '$15,000 to $19,999'}             B19001001
# B19001005  {'indent': 1, 'name': '$20,000 to $24,999'}             B19001001
#
#                                                        title    universe
# B19001001  Household Income in the Past 12 Months (In 201...  Households
# B19001002  Household Income in the Past 12 Months (In 201...  Households
# B19001003  Household Income in the Past 12 Months (In 201...  Households
# B19001004  Household Income in the Past 12 Months (In 201...  Households
# B19001005  Household Income in the Past 12 Months (In 201...  Households

# %%
# cr_income_metadata_unpacked_2 = pd.DataFrame.from_records(cr_income_metadata_unpacked['columns'])

# %%
# cr_income_metadata_unpacked_2

# %%
# result = pd.concat([df1, df3], axis=1, join='inner')
# display(result)

# %%
# result = pd.concat([cr_income_metadata_unpacked, cr_income_metadata_unpacked_2], axis=1, join='outer')
# display(result)

# %%
# df['Feature3'] = pd.DataFrame([x for x in df['dic']])['Feature3']

# %%
# cr_income_metadata_unpacked['name'] = pd.DataFrame([x for x in cr_income_metadata_unpacked['columns']])['name']

# %%
cr_income_metadata_unpacked['name'] = cr_income_metadata_unpacked['columns'].apply(lambda x: x.get('name'))

# %%
cr_income_metadata_unpacked.reset_index(inplace=True)

# %%
cr_income_metadata_unpacked.head()
# Out:
#        index                                      columns  \
# 0  B19001001              {'indent': 0, 'name': 'Total:'}
# 1  B19001002   {'indent': 1, 'name': 'Less than $10,000'}
# 2  B19001003  {'indent': 1, 'name': '$10,000 to $14,999'}
# 3  B19001004  {'indent': 1, 'name': '$15,000 to $19,999'}
# 4  B19001005  {'indent': 1, 'name': '$20,000 to $24,999'}
#
#   denominator_column_id                                              title  \
# 0             B19001001  Household Income in the Past 12 Months (In 201...
# 1             B19001001  Household Income in the Past 12 Months (In 201...
# 2             B19001001  Household Income in the Past 12 Months (In 201...
# 3             B19001001  Household Income in the Past 12 Months (In 201...
# 4             B19001001  Household Income in the Past 12 Months (In 201...
#
#      universe                name
# 0  Households              Total:
# 1  Households   Less than $10,000
# 2  Households  $10,000 to $14,999
# ...

# %%
cr_income.head()
# Out:
#           geoid                 name  B19001001  B19001001, Error  B19001002  \
# 0       01000US        United States  122802852            137327    7118907
# 1     04000US47            Tennessee    2654737             12964     164481
# 2  05000US47037  Davidson County, TN     289427              4247      14598
#
#    B19001002, Error  B19001003  B19001003, Error  B19001004  B19001004, Error  \
# 0             42565    4940584             35307    4838678             38067
# 1              6450     131682              6890     124022              6371
# 2              2023       9954              1559       9288              1774
#
#    ...  B19001013  B19001013, Error  B19001014  B19001014, Error  B19001015  \
# 0  ...   15752484             75827   11650162             61394    7652757
# 1  ...     334559             10968     229058              8213     130690
# 2  ...      40381              3557      26060              2677      17327
#
# ...

# %%
# dataframe1.rename(columns=dataframe2.set_index('Old_Names')['New_Names'], inplace=True)

# %%
# cr_income_2 = cr_income.rename(columns=cr_income_metadata_unpacked.set_index('Old_Names')['name'], inplace=False)

# %%
# df.rename(columns=dict(zip(df2["val1"], df2["val2"])))

# %%
cr_income_renamed_cols = cr_income.rename(columns=dict(zip(cr_income_metadata_unpacked["index"], cr_income_metadata_unpacked["name"])))

# %%
cr_income_renamed_cols
# Out:
#           geoid                 name     Total:  B19001001, Error  \
# 0       01000US        United States  122802852            137327
# 1     04000US47            Tennessee    2654737             12964
# 2  05000US47037  Davidson County, TN     289427              4247
#
#    Less than $10,000  B19001002, Error  $10,000 to $14,999  B19001003, Error  \
# 0            7118907             42565             4940584             35307
# 1             164481              6450              131682              6890
# 2              14598              2023                9954              1559
#
#    $15,000 to $19,999  B19001004, Error  ...  $75,000 to $99,999  \
# 0             4838678             38067  ...            15752484
# 1              124022              6371  ...              334559
# 2                9288              1774  ...               40381
#
#    B19001013, Error  $100,000 to $124,999  B19001014, Error  \
# 0             75827              11650162             61394
# ...

# %%
# cr_income_renamed_cols.loc[:,~cr_income_renamed_cols.columns.str.contains('^Error', case=False)]

# %%
cr_income_renamed_cols_2 = cr_income_renamed_cols[cr_income_renamed_cols.columns.drop(list(cr_income_renamed_cols.filter(regex='Error')))]

# %%
cr_income_renamed_cols_2
# Out:
#           geoid                 name     Total:  Less than $10,000  \
# 0       01000US        United States  122802852            7118907
# 1     04000US47            Tennessee    2654737             164481
# 2  05000US47037  Davidson County, TN     289427              14598
#
#    $10,000 to $14,999  $15,000 to $19,999  $20,000 to $24,999  \
# 0             4940584             4838678             5322157
# 1              131682              124022              134192
# 2                9954                9288               11791
#
#    $25,000 to $29,999  $30,000 to $34,999  $35,000 to $39,999  \
# 0             4984288             5320934             4933391
# 1              130229              135432              125867
# 2               11045               13684               13701
#
#    $40,000 to $44,999  $45,000 to $49,999  $50,000 to $59,999  \
# 0             5114120             4620661             9080796
# 1              130790              115979              210395
# ...

# %%
cr_income_renamed_cols_2_transposed = cr_income_renamed_cols_2.transpose()

# %%
cr_income_renamed_cols_2_transposed.reset_index(inplace=True)

# %%
cr_income_renamed_cols_2_transposed.head()
# Out:
#                 index              0          1                    2
# 0               geoid        01000US  04000US47         05000US47037
# 1                name  United States  Tennessee  Davidson County, TN
# 2              Total:      122802852    2654737               289427
# 3   Less than $10,000        7118907     164481                14598
# 4  $10,000 to $14,999        4940584     131682                 9954

# %%
cr_income_renamed_cols_2_transposed.columns = ['income_level', 'united_states', 'tennessee', 'davidson_county']

# %%
cr_income_renamed_cols_2_transposed.head()
# Out:
#          income_level  united_states  tennessee      davidson_county
# 0               geoid        01000US  04000US47         05000US47037
# 1                name  United States  Tennessee  Davidson County, TN
# 2              Total:      122802852    2654737               289427
# 3   Less than $10,000        7118907     164481                14598
# 4  $10,000 to $14,999        4940584     131682                 9954

# %%
cr_income_renamed_cols_2_transposed_2 = cr_income_renamed_cols_2_transposed.drop(index=[0,1,2]).reset_index(drop=True)

# %%
cr_income_renamed_cols_2_transposed_2
# Out:
#             income_level united_states tennessee davidson_county
# 0      Less than $10,000       7118907    164481           14598
# 1     $10,000 to $14,999       4940584    131682            9954
# 2     $15,000 to $19,999       4838678    124022            9288
# 3     $20,000 to $24,999       5322157    134192           11791
# 4     $25,000 to $29,999       4984288    130229           11045
# 5     $30,000 to $34,999       5320934    135432           13684
# 6     $35,000 to $39,999       4933391    125867           13701
# 7     $40,000 to $44,999       5114120    130790           13929
# 8     $45,000 to $49,999       4620661    115979           12484
# 9     $50,000 to $59,999       9080796    210395           24257
# 10    $60,000 to $74,999      12247929    280302           29989
# 11    $75,000 to $99,999      15752484    334559           40381
# 12  $100,000 to $124,999      11650162    229058           26060
# ...

# %%
cr_income_renamed_cols_2_transposed_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   income_level     16 non-null     object
#  1   united_states    16 non-null     object
#  2   tennessee        16 non-null     object
#  3   davidson_county  16 non-null     object
# dtypes: object(4)
# memory usage: 640.0+ bytes

# %%
plt.bar(cr_income_renamed_cols_2_transposed_2['income_level'],\
        cr_income_renamed_cols_2_transposed_2['davidson_county'],\
        color = '#53b92b')
# plt.xticks(rotation=90)
plt.title('Davidson County, TN Household Incomes')
plt.xlabel('Income Levels')
plt.ylabel('Number of Households')
plt.xticks(rotation=45,
        horizontalalignment="right")
# plt.ylim(0, 3250) 
;
# Out:
# ''

# %%
plt.bar(cr_income_renamed_cols_2_transposed_2['income_level'],\
        (cr_income_renamed_cols_2_transposed_2['davidson_county']\
        /cr_income_renamed_cols_2_transposed_2['davidson_county'].sum())*100,\
        color = 'blue')
# plt.xticks(rotation=90)
plt.title('Davidson County, TN Household Incomes')
plt.xlabel('Income Levels')
plt.ylabel('Percent of Households')
plt.xticks(rotation=45,
        horizontalalignment="right")
# plt.ylim(0, 3250) 
;
# Out:
# ''

# %% [markdown]
# ### TN Report Card Exploration

# %%
# reportcard.shape

# %%
# reportcard.head(25)

# %%
# reportcard.info()

# %%
# reportcard_transposed = reportcard.transpose()

# %%
# reportcard_transposed.head()

# %%
# reportcard_transposed.info()

# %%
# bool_series = pd.notnull(reportcard_transposed)
 
# # displayed data only with team = NaN
# reportcard_transposed[bool_series]

# %%
# reportcard_transposed

# %% [markdown]
# ### TN Ready to Graduate Exploration 2019

# %%
ready_grad_19.shape
# Out:
# (1711, 6)

# %%
ready_grad_19.head()
# Out:
#    system      system_name                          subgroup  n_count  \
# 0      10  Anderson County                      All Students      552
# 1      10  Anderson County  American Indian or Alaska Native        2
# 2      10  Anderson County                             Asian        8
# 3      10  Anderson County         Black or African American       10
# 4      10  Anderson County    Black/Hispanic/Native American       19
#
#   n_ready_grad pct_ready_grad
# 0          237           42.9
# 1            *              *
# 2            *              *
# 3            1             10
# 4            5           26.3

# %%
ready_grad_19.tail()
# Out:
#       system                  system_name                        subgroup  \
# 1706     985  Achievement School District            Non-English Learners
# 1707     985  Achievement School District  Non-Students with Disabilities
# 1708     985  Achievement School District      Students with Disabilities
# 1709     985  Achievement School District                  Super Subgroup
# 1710     985  Achievement School District                           White
#
#       n_count n_ready_grad pct_ready_grad
# 1706      664           15            2.3
# 1707      577           15            2.6
# 1708      110           **             **
# 1709      680           15            2.2
# 1710       18           **             **

# %%
ready_grad_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1711 entries, 0 to 1710
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   system          1711 non-null   int64
#  1   system_name     1711 non-null   object
#  2   subgroup        1711 non-null   object
#  3   n_count         1711 non-null   int64
#  4   n_ready_grad    1711 non-null   object
#  5   pct_ready_grad  1711 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 80.3+ KB

# %%
ready_grad_19['subgroup'].unique()
# Out:
# array(['All Students', 'American Indian or Alaska Native', 'Asian',
#        'Black or African American', 'Black/Hispanic/Native American',
#        'Economically Disadvantaged',
#        'English Learners with Transitional 1-4', 'Hispanic',
#        'Non-Economically Disadvantaged', 'Non-English Learners',
#        'Non-Students with Disabilities', 'Students with Disabilities',
#        'Super Subgroup', 'White',
#        'Native Hawaiian or Other Pacific Islander'], dtype=object)

# %%
ready_grad_19_all_ed = ready_grad_19.loc[(ready_grad_19['subgroup'] == 'All Students')\
                                         |(ready_grad_19['subgroup'] == 'Economically Disadvantaged')]

# %%
ready_grad_19_all_ed.head()
# Out:
#     system      system_name                    subgroup  n_count n_ready_grad  \
# 0       10  Anderson County                All Students      552          237
# 5       10  Anderson County  Economically Disadvantaged      208           59
# 14      12        Oak Ridge                All Students      304          199
# 19      12        Oak Ridge  Economically Disadvantaged       80           40
# 29      20   Bedford County                All Students      632          189
#
#    pct_ready_grad
# 0            42.9
# 5            28.4
# 14           65.5
# 19             50
# 29           29.9

# %%
ready_grad_19_all_ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261 entries, 0 to 1702
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   system          261 non-null    int64
#  1   system_name     261 non-null    object
#  2   subgroup        261 non-null    object
#  3   n_count         261 non-null    int64
#  4   n_ready_grad    261 non-null    object
#  5   pct_ready_grad  261 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 14.3+ KB

# %%
ready_grad_19_all_ed['n_ready_grad'].value_counts()
# Out:
# 14      8
# 39      6
# 24      6
# **      5
# 23      5
#        ..
# 72      1
# 1032    1
# 1123    1
# 339     1
# 189     1
# Name: n_ready_grad, Length: 148, dtype: int64

# %%
# ready_grad_19_all_ed['n_ready_grad'] = ready_grad_19_all_ed['n_ready_grad']\
#     .str.replace('**','0').astype(int)

# %%
# mnps_hs_dem['econ_dis_pct'] = mnps_hs_dem['Economically Disadvantaged']\
#     .str.replace(r'\D','').astype(float)

# %%
# sub_ready_grad = ready_grad_19_all_ed.loc[(ready_grad_19_all_ed['n_ready_grad'] == '*')\
#                                          |(ready_grad_19_all_ed['n_ready_grad'] == '**')]

# %%
ready_grad_19_all_ed_sub = ready_grad_19_all_ed.drop(ready_grad_19_all_ed[(ready_grad_19_all_ed['n_ready_grad'] == '*')\
                | (ready_grad_19_all_ed['n_ready_grad'] == '**')].index)

# %%
ready_grad_19_all_ed_sub
# Out:
#       system                  system_name                    subgroup  \
# 0         10              Anderson County                All Students
# 5         10              Anderson County  Economically Disadvantaged
# 14        12                    Oak Ridge                All Students
# 19        12                    Oak Ridge  Economically Disadvantaged
# 29        20               Bedford County                All Students
# ...      ...                          ...                         ...
# 1635     950                Wilson County  Economically Disadvantaged
# 1651     961       Alvin C York Institute                All Students
# 1654     961       Alvin C York Institute  Economically Disadvantaged
# 1697     985  Achievement School District                All Students
# 1702     985  Achievement School District  Economically Disadvantaged
#
#       n_count n_ready_grad pct_ready_grad
# 0         552          237           42.9
# ...

# %%
ready_grad_19_all_ed_sub_2 = ready_grad_19_all_ed_sub.drop(ready_grad_19_all_ed_sub[(ready_grad_19_all_ed_sub['pct_ready_grad'] == '*')\
                | (ready_grad_19_all_ed_sub['pct_ready_grad'] == '**')].index)

# %%
ready_grad_19_all_ed_sub_2
# Out:
#       system                  system_name                    subgroup  \
# 0         10              Anderson County                All Students
# 5         10              Anderson County  Economically Disadvantaged
# 14        12                    Oak Ridge                All Students
# 19        12                    Oak Ridge  Economically Disadvantaged
# 29        20               Bedford County                All Students
# ...      ...                          ...                         ...
# 1635     950                Wilson County  Economically Disadvantaged
# 1651     961       Alvin C York Institute                All Students
# 1654     961       Alvin C York Institute  Economically Disadvantaged
# 1697     985  Achievement School District                All Students
# 1702     985  Achievement School District  Economically Disadvantaged
#
#       n_count n_ready_grad pct_ready_grad
# 0         552          237           42.9
# ...

# %%
ready_grad_19_all_ed_sub_2['n_ready_grad'] = ready_grad_19_all_ed_sub_2['n_ready_grad'].astype(int)

# %%
ready_grad_19_all_ed_sub_2['pct_ready_grad'] = ready_grad_19_all_ed_sub_2['pct_ready_grad'].astype(float)

# %%
ready_grad_19_all_ed_sub_2.head()
# Out:
#     system      system_name                    subgroup  n_count  \
# 0       10  Anderson County                All Students      552
# 5       10  Anderson County  Economically Disadvantaged      208
# 14      12        Oak Ridge                All Students      304
# 19      12        Oak Ridge  Economically Disadvantaged       80
# 29      20   Bedford County                All Students      632
#
#     n_ready_grad  pct_ready_grad
# 0            237            42.9
# 5             59            28.4
# 14           199            65.5
# 19            40            50.0
# 29           189            29.9

# %%
ready_grad_19_all_ed_sub_2.describe()
# Out:
#            system      n_count  n_ready_grad  pct_ready_grad
# count  251.000000   251.000000     251.00000      251.000000
# mean   474.282869   398.936255     142.23506       34.451793
# std    289.133484   851.474197     306.30067       14.036359
# min     10.000000    10.000000       2.00000        1.800000
# 25%    225.000000    81.000000      23.00000       24.250000
# 50%    480.000000   182.000000      51.00000       32.700000
# 75%    750.000000   323.000000     123.50000       43.200000
# max    985.000000  7906.000000    2501.00000       82.400000

# %%
davidson_ready_grad_19 = ready_grad_19_all_ed_sub_2.loc\
    [(ready_grad_19_all_ed_sub_2['system_name'].isin(['Davidson County']))]

# %%
davidson_ready_grad_19
# Out:
#      system      system_name                    subgroup  n_count  \
# 382     190  Davidson County                All Students     5612
# 387     190  Davidson County  Economically Disadvantaged     3330
#
#      n_ready_grad  pct_ready_grad
# 382          1677            29.9
# 387           605            18.2

# %%
plt.bar(davidson_ready_grad_19['subgroup'],\
        davidson_ready_grad_19['pct_ready_grad'],\
        color = '#53b92b')
# plt.xticks(rotation=90)
plt.title('Davidson County 2019, Percent Ready to Graduate')
plt.xlabel('Subgroup')
plt.ylabel('Percent Ready to Graduate')
plt.xticks(rotation=45,
        horizontalalignment="right")
# plt.ylim(0, 3250) 
;
# Out:
# ''

# %% [markdown]
# ### TN Ready to Graduate Exploration 2018

# %%
ready_grad_18
# Out:
#       system                  system_name                          subgroup  \
# 0         10              Anderson County                      All Students
# 1         10              Anderson County  American Indian or Alaska Native
# 2         10              Anderson County                             Asian
# 3         10              Anderson County         Black or African American
# 4         10              Anderson County    Black/Hispanic/Native American
# ...      ...                          ...                               ...
# 1693     985  Achievement School District              Non-English Learners
# 1694     985  Achievement School District    Non-Students with Disabilities
# 1695     985  Achievement School District        Students with Disabilities
# 1696     985  Achievement School District                    Super Subgroup
# 1697     985  Achievement School District                             White
#
#       n_count n_ready_grad pct_ready_grad
# ...

# %%
davidson_ready_grad_18 = ready_grad_18.loc\
    [(ready_grad_18['system_name'].isin(['Davidson County']))]

# %%
davidson_ready_grad_18
# Out:
#      system      system_name                                   subgroup  \
# 370     190  Davidson County                               All Students
# 371     190  Davidson County           American Indian or Alaska Native
# 372     190  Davidson County                                      Asian
# 373     190  Davidson County                  Black or African American
# 374     190  Davidson County             Black/Hispanic/Native American
# 375     190  Davidson County                 Economically Disadvantaged
# 376     190  Davidson County     English Learners with Transitional 1-4
# 377     190  Davidson County                                   Hispanic
# 378     190  Davidson County  Native Hawaiian or Other Pacific Islander
# 379     190  Davidson County             Non-Economically Disadvantaged
# 380     190  Davidson County                       Non-English Learners
# 381     190  Davidson County             Non-Students with Disabilities
# ...

# %% [markdown]
# ### TN ACT Score Data by District 2019

# %%
act_19
# Out:
#      District                District Name                        Subgroup  \
# 0          10              Anderson County                    All Students
# 1          10              Anderson County  Black/Hispanic/Native American
# 2          10              Anderson County      Economically Disadvantaged
# 3          10              Anderson County      Students with Disabilities
# 4          12                    Oak Ridge                    All Students
# ..        ...                          ...                             ...
# 597       985  Achievement School District                    All Students
# 598       985  Achievement School District  Black/Hispanic/Native American
# 599       985  Achievement School District      Economically Disadvantaged
# 600       985  Achievement School District                English Learners
# 601       985  Achievement School District      Students with Disabilities
#
# ...

# %%
davidson_act_19 = act_19.loc\
    [(act_19['District Name'].isin(['Davidson County']))]

# %%
davidson_act_19
# Out:
#      District    District Name                        Subgroup  Valid Tests  \
# 129       190  Davidson County                    All Students         4307
# 130       190  Davidson County  Black/Hispanic/Native American         2913
# 131       190  Davidson County      Economically Disadvantaged         2316
# 132       190  Davidson County                English Learners          603
# 133       190  Davidson County      Students with Disabilities          381
#
#     Participation Rate Average English Score Average Math Score  \
# 129                 92                    18               17.9
# 130                 92                  16.2               16.7
# 131                 91                  15.9               16.7
# 132                 87                  12.5               15.3
# 133                 88                  13.7               15.4
#
#     Average Reading Score Average Science Score Average Composite Score  \
# ...

# %%
davidson_act_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 129 to 133
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   District                      5 non-null      int64
#  1   District Name                 5 non-null      object
#  2   Subgroup                      5 non-null      object
#  3   Valid Tests                   5 non-null      int64
#  4   Participation Rate            5 non-null      object
#  5   Average English Score         5 non-null      object
#  6   Average Math Score            5 non-null      object
#  7   Average Reading Score         5 non-null      object
#  8   Average Science Score         5 non-null      object
#  9   Average Composite Score       5 non-null      object
#  10  Number Scoring 21 or Higher   5 non-null      object
#  11  Percent Scoring 21 or Higher  5 non-null      object
# ...

# %%
davidson_act_19['Average Composite Score'] = davidson_act_19['Average Composite Score'].astype(float)
# Out:
# <ipython-input-123-06a6b63e2ab0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   davidson_act_19['Average Composite Score'] = davidson_act_19['Average Composite Score'].astype(float)

# %%
davidson_act_19['Percent Scoring Below 19'] = davidson_act_19['Percent Scoring Below 19'].astype(float)
# Out:
# <ipython-input-124-c18a9bec4b7a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   davidson_act_19['Percent Scoring Below 19'] = davidson_act_19['Percent Scoring Below 19'].astype(float)

# %%
davidson_act_19['Percent Scoring 21 or Higher'] = davidson_act_19['Percent Scoring 21 or Higher'].astype(float)
# Out:
# <ipython-input-125-0dc13c32b8ff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   davidson_act_19['Percent Scoring 21 or Higher'] = davidson_act_19['Percent Scoring 21 or Higher'].astype(float)

# %%
plt.bar(davidson_act_19['Subgroup'],\
        davidson_act_19['Average Composite Score'],\
        color = '#53b92b')
# plt.xticks(rotation=90)
plt.title('Davidson County 2019, Average Composite Score')
plt.xlabel('Subgroup')
plt.ylabel('Average Composite Score')
plt.xticks(rotation=45,
        horizontalalignment="right")
# plt.ylim(0, 3250) 
;
# Out:
# ''

# %%
plt.bar(davidson_act_19['Subgroup'],\
        davidson_act_19['Percent Scoring Below 19'],\
        color = '#53b92b')
# plt.xticks(rotation=90)
plt.title('Davidson County 2019, Percent Scoring Below 19')
plt.xlabel('Subgroup')
plt.ylabel('Percent Scoring Below 19')
plt.xticks(rotation=45,
        horizontalalignment="right")
# plt.ylim(0, 3250) 
;
# Out:
# ''

# %%
plt.bar(davidson_act_19['Subgroup'],\
        davidson_act_19['Percent Scoring 21 or Higher'],\
        color = '#53b92b')
# plt.xticks(rotation=90)
plt.title('Davidson County 2019, Percent Scoring 21 or Higher')
plt.xlabel('Subgroup')
plt.ylabel('Percent Scoring 21 or Higher')
plt.xticks(rotation=45,
        horizontalalignment="right")
# plt.ylim(0, 3250) 
;
# Out:
# ''

# %% [markdown]
# ### TN School Indicator Scores by District 2019

# %%
school_indicators_19
# Out:
#        system                         system_name  school  \
# 0          10                     Anderson County       2
# 1          10                     Anderson County       2
# 2          10                     Anderson County       2
# 3          10                     Anderson County       2
# 4          10                     Anderson County       2
# ...       ...                                 ...     ...
# 19937     986  Tennessee State Board of Education    8005
# 19938     986  Tennessee State Board of Education    8005
# 19939     986  Tennessee State Board of Education    8005
# 19940     986  Tennessee State Board of Education    8005
# 19941     986  Tennessee State Board of Education    8005
#
#                        school_name pool  designation_ineligible  \
# 0      Anderson County High School   HS                     0.0
# 1      Anderson County High School   HS                     0.0
# 2      Anderson County High School   HS                     0.0
# ...

# %%
davidson_school_indicators_19 = school_indicators_19.loc\
    [(school_indicators_19['system_name'].isin(['Davidson County']))]

# %%
davidson_school_indicators_19
# Out:
#       system      system_name  school              school_name pool  \
# 2710     190  Davidson County       1  A. Z. Kelley Elementary   K8
# 2711     190  Davidson County       1  A. Z. Kelley Elementary   K8
# 2712     190  Davidson County       1  A. Z. Kelley Elementary   K8
# 2713     190  Davidson County       1  A. Z. Kelley Elementary   K8
# 2714     190  Davidson County       1  A. Z. Kelley Elementary   K8
# ...      ...              ...     ...                      ...  ...
# 4537     190  Davidson County    8105       KA @ The Crossings   K8
# 4538     190  Davidson County    8105       KA @ The Crossings   K8
# 4539     190  Davidson County    8105       KA @ The Crossings   K8
# 4540     190  Davidson County    8105       KA @ The Crossings   K8
# 4541     190  Davidson County    8105       KA @ The Crossings   K8
#
#       designation_ineligible                        subgroup  \
# 2710                     0.0                    All Students
# ...

# %%
davidson_school_indicators_19['pool'].value_counts()
# Out:
# K8    1554
# HS     278
# Name: pool, dtype: int64

# %%
davidson_hs_school_indicators_19 = davidson_school_indicators_19.loc\
    [(davidson_school_indicators_19['pool'].isin(['HS']))]

# %%
davidson_hs_school_indicators_19
# Out:
#       system      system_name  school                            school_name  \
# 2766     190  Davidson County      20                    Antioch High School
# 2767     190  Davidson County      20                    Antioch High School
# 2768     190  Davidson County      20                    Antioch High School
# 2769     190  Davidson County      20                    Antioch High School
# 2770     190  Davidson County      20                    Antioch High School
# ...      ...              ...     ...                                    ...
# 4325     190  Davidson County    8011  KIPP Nashville Collegiate High School
# 4326     190  Davidson County    8011  KIPP Nashville Collegiate High School
# 4327     190  Davidson County    8011  KIPP Nashville Collegiate High School
# 4328     190  Davidson County    8011  KIPP Nashville Collegiate High School
# 4329     190  Davidson County    8011  KIPP Nashville Collegiate High School
#
# ...

# %%
davidson_hs_school_indicators_19['subgroup'].value_counts()
# Out:
# Super Subgroup                               23
# Black/Hispanic/Native American               23
# Students with Disabilities                   23
# Hispanic                                     23
# White                                        23
# Economically Disadvantaged                   23
# Subgroups                                    23
# English Learners with Transitional 1-4       23
# All Students                                 23
# Black or African American                    23
# Asian                                        22
# American Indian or Alaska Native             14
# Native Hawaiian or Other Pacific Islander    12
# Name: subgroup, dtype: int64

# %%
davidson_hs_school_indicators_19_all_ed = davidson_hs_school_indicators_19.loc\
    [(davidson_hs_school_indicators_19['subgroup'] == 'All Students')\
    |(davidson_hs_school_indicators_19['subgroup'] == 'Economically Disadvantaged')]

# %%
davidson_hs_school_indicators_19_all_ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 2766 to 4323
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   system                  46 non-null     int64
#  1   system_name             46 non-null     object
#  2   school                  46 non-null     int64
#  3   school_name             46 non-null     object
#  4   pool                    46 non-null     object
#  5   designation_ineligible  46 non-null     float64
#  6   subgroup                46 non-null     object
#  7   score_achievement       39 non-null     float64
#  8   score_growth            41 non-null     float64
#  9   score_absenteeism       40 non-null     float64
#  10  score_grad              40 non-null     float64
#  11  score_ready_grad        38 non-null     float64
#  12  score_elpa              24 non-null     float64
# dtypes: float64(7), int64(2), object(4)
# memory usage: 5.0+ KB

# %%
davidson_hs_school_indicators_19_all_ed
# Out:
#       system      system_name  school                            school_name  \
# 2766     190  Davidson County      20                    Antioch High School
# 2771     190  Davidson County      20                    Antioch High School
# 2858     190  Davidson County      77                 Cane Ridge High School
# 2863     190  Davidson County      77                 Cane Ridge High School
# 3088     190  Davidson County     203      East Nashville Magnet High School
# 3093     190  Davidson County     203      East Nashville Magnet High School
# 3147     190  Davidson County     245                  Glencliff High School
# 3152     190  Davidson County     245                  Glencliff High School
# 3375     190  Davidson County     335                         Hillsboro High
# 3380     190  Davidson County     335                         Hillsboro High
# 3387     190  Davidson County     340                          Hillwood High
# ...

# %%
davidson_hs_school_indicators_19_all_ed_sorted = davidson_hs_school_indicators_19_all_ed.sort_values\
(by = 'score_ready_grad', ascending = False)

# %%
plt.bar(davidson_hs_school_indicators_19_all_ed_sorted['school_name'],\
        davidson_hs_school_indicators_19_all_ed_sorted['score_ready_grad'],\
        color = '#53b92b')
# plt.xticks(rotation=90)
plt.title('Davidson County 2019, score_ready_grad')
plt.xlabel('Subgroup')
plt.ylabel('score_ready_grad')
plt.xticks(rotation=45,
        horizontalalignment="right")
# plt.ylim(0, 3250) 
;
# Out:
# ''
